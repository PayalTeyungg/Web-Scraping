# %%
import os

# Change the current working directory
os.chdir('/Users/payalteyung/Desktop/DA')

# Verify the change
print(os.getcwd())
# Out:
# /Users/payalteyung/Desktop/DA

# %%
import os
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import logging

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
def scrape_setopati_images(base_url, output_folder):
    try:
        headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
        response = requests.get(base_url, headers=headers)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')

        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        articles = soup.find_all('div', class_='items')
        images = []

        for index, article in enumerate(articles):
            title_tag = article.find('span', class_='main-title')
            title = title_tag.text.strip() if title_tag else f"Untitled_{index}"
            sanitized_title = "_".join(title.split()).replace("/", "-")

            img_tag = article.find('img')
            if img_tag and 'src' in img_tag.attrs:
                img_url = urljoin(base_url, img_tag['src'])
                images.append({"title": title, "image_url": img_url})

                try:
                    img_response = requests.get(img_url, stream=True, headers=headers)
                    img_response.raise_for_status()

                    img_path = os.path.join(output_folder, f"{sanitized_title}_{index}.jpg")
                    with open(img_path, 'wb') as img_file:
                        for chunk in img_response.iter_content(1024):
                            img_file.write(chunk)

                    logging.info(f"Downloaded: {title}")
                except requests.exceptions.RequestException as e:
                    logging.error(f"Failed to download image for {title}: {e}")
            else:
                logging.warning(f"No image found for: {title}")

        
            time.sleep(1)

        return images

    except Exception as e:
        logging.error(f"An error occurred: {e}")
        return []

# %%
if __name__ == "__main__":
    base_url = "https://www.setopati.com/"  
    output_folder = "setopati_images"

    images_and_titles = scrape_setopati_images(base_url, output_folder)
    logging.info("Scraped images and titles:")
    for item in images_and_titles:
        logging.info(f"Title: {item['title']}, Image URL: {item['image_url']}")
# Out:
# 2024-12-30 13:28:50,132 - INFO - Downloaded: नेप्सेले गर्‍यो सात कम्पनीको मूल्य समायोजन, नयाँ मूल्य कति?
# 2024-12-30 13:28:51,437 - INFO - Downloaded: 'नेपालमा पनि कोही बस्छ र!'
# 2024-12-30 13:28:52,754 - INFO - Downloaded: चीनले ब्रह्मपुत्रमा बनाउन लागेको विशाल जलविद्युत आयोजनाले के असर गर्छ नेपाललाई?
# 2024-12-30 13:28:53,760 - WARNING - No image found for: Untitled_3
# 2024-12-30 13:28:55,084 - INFO - Downloaded: छोराहरूले लत्तो छाडेको व्यवसाय सम्हालेर वर्षकै २० लाख कमाइरहेको दम्पती
# 2024-12-30 13:28:56,396 - INFO - Downloaded: चालक र माली काम गर्ने आले दम्पतीले हुर्काएका चार सन्तान
# 2024-12-30 13:28:57,721 - INFO - Downloaded: रातको चिया व्यापार
# 2024-12-30 13:28:59,051 - INFO - Downloaded: अब विकट छैन ‘बोबाङ गाउँ’
# 2024-12-30 13:29:00,352 - INFO - Downloaded: कोरियामा सिकेर बेच्न थाले मासु, लगानी पुग्यो २ करोड
# 2024-12-30 13:29:01,675 - INFO - Downloaded: चौथो टेस्टमा भारतमाथि अस्ट्रेलियाको जित, सिरिजमा लियो अग्रता
# 2024-12-30 13:29:03,012 - INFO - Downloaded: भारत र अस्ट्रेलियाबीचको टेस्ट हेर्ने दर्शकको संख्याले बनायो कीर्तिमान
# 2024-12-30 13:29:04,320 - INFO - Downloaded: सोमबार बढ्यो सुनको भाउ, कतिमा हुँदैछ किनबेच?
# 2024-12-30 13:29:05,634 - INFO - Downloaded: १३ वर्षीया बालिकालाई जबरजस्ती घर भित्र्याउने युवक पक्राउ
# 2024-12-30 13:29:06,987 - INFO - Downloaded: भक्तपुरका विभिन्न स्थानमा आज १० घन्टा विद्युत अवरूद्ध हुने
# 2024-12-30 13:29:08,300 - INFO - Downloaded: अमेरिकाका पूर्वराष्ट्रपति जिमी कार्टरको निधन
# 2024-12-30 13:29:09,633 - INFO - Downloaded: घट्यो काठमाडौंको न्यूनतम तापक्रम
# 2024-12-30 13:29:10,977 - INFO - Downloaded: यस्तो छ आजका लागि विदेशी मुद्राको विनिमयदर
# 2024-12-30 13:29:12,301 - INFO - Downloaded: थप एक नेपालीमा पुष्टि भयो मंकिपक्स
# 2024-12-30 13:29:13,620 - INFO - Downloaded: आज तमु ल्होसार मनाइँदै
# 2024-12-30 13:29:14,934 - INFO - Downloaded: अखिल (क्रान्तिकारी) मा लाग्यो ३२ वर्ष उमेर हद
# 2024-12-30 13:29:16,351 - INFO - Downloaded: यस्तो रहनेछ आज दिनभरिको मौसम
# 2024-12-30 13:29:17,665 - INFO - Downloaded: जनमतको निर्देशन: पार्टी वा नेतृत्वबारे सामाजिक सञ्जालमा हरेक दिन एउटा सकारात्मक पोस्ट गर्नुपर्ने
# 2024-12-30 13:29:18,975 - INFO - Downloaded: तीन जना एउटै कारमा गए, बाटोमा एक जनाको हत्या
# 2024-12-30 13:29:20,303 - INFO - Downloaded: यसरी बन्दैछ १ हजार १२६ मिटर लामो सुरूङ (भिडिओ)
# 2024-12-30 13:29:21,602 - INFO - Downloaded: पिकनिक मनाउन जाँदा बाघको शिकार
# 2024-12-30 13:29:22,937 - INFO - Downloaded: गोवाबाट सिकेर पोखरामा स्ट्रिट फेस्टिभल (भिडिओ)
# 2024-12-30 13:29:24,259 - INFO - Downloaded: ग्रिनल्यान्ड, पनामा र क्यानडामाथि नियन्त्रण जमाउने ट्रम्पको धम्की (भिडिओ)
# 2024-12-30 13:29:25,590 - INFO - Downloaded: 'अहिलेको समयमा डेटा भनेको सुन हो'
# 2024-12-30 13:29:26,905 - INFO - Downloaded: लगातार हिट गीत गाइरहेका अर्जुन
# 2024-12-30 13:29:28,365 - INFO - Downloaded: १६० किलो गाँजा र ट्रकसहित दुई जना पक्राउ
# 2024-12-30 13:29:29,675 - INFO - Downloaded: अखिल (क्रान्तिकारी)मा ३२ वर्षे उमेर हद लागु, माघ ५ गते मनोनयन दर्ता
# 2024-12-30 13:29:31,117 - INFO - Downloaded: कुखुराको मासु खाँदा एक जनाको मृत्यु, तीन बिरामी
# 2024-12-30 13:29:33,017 - INFO - Downloaded: तिम्बुङ पोखरी ।ताप्लेजुङको सिदिङ्वा गाउँपालिकास्थित धार्मिक तथा पर्यटकीयस्थल तिम्बुङ पोखरीको रमणीय दृश्य। तस्बिर: सन्तोष पुर्कुटी/रासस
# 2024-12-30 13:29:34,663 - INFO - Downloaded: कुहिरोले ढाकेको मङ्गगलसेन ।अछामको मंगलसेन नगरपालिका-६ ठुलासैनबाट सोमबार बिहान कुहिरोले ढाकेको अछाम सदरमुकाम मंगलसेन लगायत आसपासको क्षेत्र। तस्बिर: सुशील भण्डारी/रासस
# 2024-12-30 13:29:36,358 - INFO - Downloaded: फेवातालमा ‘ड्रागन बोट रेस फेस्टिभल’ ।पोखरामा दोस्रो संस्करणको जारी ‘नेपाल–चीन मैत्रीपूर्ण ड्रागन बोट रेस फेस्टिभल’मा सोमबार पाँचसय मिटरको फाइनल खेलका लागि प्रतिस्पर्धा गर्दै चाइनिज टिम। तस्बिरः राधिका कँडेल/रासस
# 2024-12-30 13:29:37,946 - INFO - Downloaded: नुम्बुर हिमाल ।सोलुखुम्बुको सल्लेरीबाट सोमबार बिहान देखिएको सोलुखुम्बुस्थित नुम्बुर हिमाल। ६ हजार ९५८ मिटर उचाइमा रहेको रहेको यस हिमालमा अहिले हिउँ रित्तिँदै गएको छ। तस्बिर: सुवास दर्नाल/रासस
# 2024-12-30 13:29:39,626 - INFO - Downloaded: साइपाल हिमाल ।बझाङ जिल्लाको साइपाल गाउँपालिकास्थित साइपाल हिमाल। सात हजार ३१ मिटर उचाइमा रहेको यो हिमालको फेदीमा पुग्न जिल्ला सदरमुकाम चैनपुरबाट करिब ६ दिन पैदल हिँड्नुपर्छ। तस्बिर: भूमिराज पिठातोली/रासस
# 2024-12-30 13:29:40,947 - INFO - Downloaded: 'बन्दीपुर भ्रमण वर्ष २०२५' आयोजना, पर्यटकको औसत बसाइ तीन दिन बनाइने
# 2024-12-30 13:29:42,257 - INFO - Downloaded: सोमबार बढ्यो सुनको भाउ, कतिमा हुँदैछ किनबेच?
# 2024-12-30 13:29:43,584 - INFO - Downloaded: नेप्सेले गर्‍यो सात कम्पनीको मूल्य समायोजन, नयाँ मूल्य कति?
# 2024-12-30 13:29:45,012 - INFO - Downloaded: तीन साथीले २४ लाखमा खोलेको रेस्टुरेन्ट, अहिले काम गर्छन् ३५० जना
# 2024-12-30 13:29:46,359 - INFO - Downloaded: यसरी बन्दैछ १ हजार १२६ मिटर लामो सुरूङ (भिडिओ)
# 2024-12-30 13:29:47,737 - INFO - Downloaded: २६०९ विन्दुमा नेप्से, साढे पाँच अर्बको सेयर किनबेच
# 2024-12-30 13:29:49,076 - INFO - Downloaded: लुक्लाबाट उडेको हेलिकप्टरमा ठोक्कियो चरा, साँगामा आकस्मिक अवतरण
# 2024-12-30 13:29:50,654 - INFO - Downloaded: सोमबार भृकुटीमण्डपमा च्याउ मेला हुने
# 2024-12-30 13:29:51,972 - INFO - Downloaded: मन्त्री पाण्डेले गरे निर्माणाधीन नेपालगञ्ज विमानस्थल निरीक्षण
# 2024-12-30 13:29:53,285 - INFO - Downloaded: परराष्ट्र मन्त्री राणाले गरिन् ५ अर्ब लगानीमा बन्ने जालपादेवी केबलकार शिलान्यास
# 2024-12-30 13:29:54,627 - INFO - Downloaded: घट्यो सुन–चाँदीको भाउ, आज कतिमा हुँदैछ किनबेच?
# 2024-12-30 13:29:55,971 - INFO - Downloaded: बेनी–रणवाङ–दरवाङ सडक स्तरोन्नति हुँदै
# 2024-12-30 13:29:57,291 - INFO - Downloaded: चितवनमा विद्युतीय कार एक्सपेङ जी सिक्सको बिक्री सुरु
# 2024-12-30 13:29:58,622 - INFO - Downloaded: पर्यटन प्रबर्द्धनका लागि मेघौलीदेखि बारपाकसम्म मोटरसाइकल राइडिङ
# 2024-12-30 13:29:59,976 - INFO - Downloaded: 'बन्दीपुर भ्रमण वर्ष २०२५' आयोजना, पर्यटकको औसत बसाइ तीन दिन बनाइने
# 2024-12-30 13:30:01,301 - INFO - Downloaded: नेपाल फ्रेट फरवार्डस एसोसिएसनको अध्यक्षमा राजेन्द्र संग्रौला निर्वाचित
# 2024-12-30 13:30:02,649 - INFO - Downloaded: नौ बुँदे घोषणा पत्र जारी गर्दै सकियो उद्योग तथा व्यवसाय महासंघको राष्ट्रिय भेला
# 2024-12-30 13:30:03,985 - INFO - Downloaded: 'मेरो नयाँ व्यवसायले नसोचेको सफलता दिएको छ'
# 2024-12-30 13:30:05,373 - INFO - Downloaded: फुर्सदमा सुरू भएको 'बौचा' लाई ब्रान्ड बनाउँदै महर्जन दम्पती
# 2024-12-30 13:30:06,697 - INFO - Downloaded: भारतबाट फर्केर 'निनो' बनाइरहेका उज्ज्वल
# 2024-12-30 13:30:08,047 - INFO - Downloaded: खेर जाने कपडाका टुक्राबाट दिदीबहिनीले सुरू गरेको 'हिसी'
# 2024-12-30 13:30:09,505 - INFO - Downloaded: महमा जमेकी महालक्ष्मी
# 2024-12-30 13:30:10,841 - INFO - Downloaded: चौथो टेस्टमा भारतमाथि अस्ट्रेलियाको जित, सिरिजमा लियो अग्रता
# 2024-12-30 13:30:12,195 - INFO - Downloaded: भारत र अस्ट्रेलियाबीचको टेस्ट हेर्ने दर्शकको संख्याले बनायो कीर्तिमान
# 2024-12-30 13:30:13,568 - INFO - Downloaded: उपाधि होडमा बलियो बन्दै लिभरपुल
# 2024-12-30 13:30:14,903 - INFO - Downloaded: मिसन–२०२६ : एसियाली खेलकुदमा स्वर्णसहित दोहोरो अंकमा पदक जित्ने लक्ष्य पूरा हुने विश्वास
# 2024-12-30 13:30:16,265 - INFO - Downloaded: नेपाल जुनियर इन्टरनेसनल सिरिज ब्याडमिन्टन : सूर्यक्ष र पारुललाई उपाधि
# 2024-12-30 13:30:17,634 - INFO - Downloaded: खेलका माध्यमबाट समृद्ध मुलुक निर्माणमा योगदान पुग्छ : मन्त्री चौधरी
# 2024-12-30 13:30:19,008 - INFO - Downloaded: भारतविरूद्ध अस्ट्रेलियाको अग्रता ३ सय रन नाघ्यो
# 2024-12-30 13:30:20,522 - INFO - Downloaded: रहेनन् मलयालम अभिनेता दिलीप शंकर
# 2024-12-30 13:30:21,935 - INFO - Downloaded: हरर फिल्म 'ममी' को टिजर सार्वजनिक (भिडिओ)
# 2024-12-30 13:30:23,420 - INFO - Downloaded: व्यापार छाडेर संगीतमा लागे, ४ हजार बढीलाई सिकाइसके नाचगान
# 2024-12-30 13:30:24,837 - INFO - Downloaded: यस्तो छ सलमान खानको 'सिकन्दर' को टिजर (भिडिओ)
# 2024-12-30 13:30:26,560 - INFO - Downloaded: मञ्जु गौतमले ल्याइन् 'मुटुमा खिल बस्यो' (भिडिओ)
# 2024-12-30 13:30:27,945 - INFO - Downloaded: एस एस राजामौलीको फिल्मबाट कमब्याक गर्दै प्रियंका
# 2024-12-30 13:30:29,259 - INFO - Downloaded: 'जन्ते बाख्रो' को काठमाडौंमा शुभमुहूर्त
# 2024-12-30 13:30:30,637 - INFO - Downloaded: एनआरएनए महिला विभागले दियो बारबर्दिया नगर अस्पताललाई स्वास्थ्य उपकरण
# 2024-12-30 13:30:31,953 - INFO - Downloaded: 'बच्चाको डाक्टर हुनु र आमा हुनु फरक रहेछ'
# 2024-12-30 13:30:33,627 - INFO - Downloaded: ९ महिनाअघि मात्रै क्यानडा आएकी थिइन्, सडक दुर्घटनामा परिन्
# 2024-12-30 13:30:35,019 - INFO - Downloaded: एनआरएनए एकता महाधिवेशनमा अवरोध नगर्न सर्वोच्चको पत्र
# 2024-12-30 13:30:36,427 - INFO - Downloaded: गैरआवासीय नेपाली नागरिकताको कार्यान्वयनका लागि सरकारको ध्यानाकर्षण
# 2024-12-30 13:30:37,751 - INFO - Downloaded: अस्ट्रेलियामा गुञ्जिँदै सत्य-स्वरूप
# 2024-12-30 13:30:39,211 - INFO - Downloaded: नेपालमय सिड्नी! (तस्बिरहरू)
# 2024-12-30 13:30:40,565 - INFO - Downloaded: साहसिक साइक्लिङको नयाँ गन्तव्य च्योर्दोङ
# 2024-12-30 13:30:42,068 - INFO - Downloaded: सिरानचोकमा क्होइबो धींले लोभ्याउँदैछ पर्यटक (तस्बिरहरू)
# 2024-12-30 13:30:43,522 - INFO - Downloaded: चेर्दुङ डाँडामा साइकल सरर... (तस्बिरहरू)
# 2024-12-30 13:30:44,847 - INFO - Downloaded: कञ्चनजंघा पदमार्गको जरूरी सूचना!
# 2024-12-30 13:30:46,184 - INFO - Downloaded: मलाई हरेक साल हिँडाएर हिमाल पुर्‍याउने संगीत!
# 2024-12-30 13:30:47,493 - INFO - Downloaded: थोबो डाँडामा १२ सय पल्टनसँग पल्टिँदा (तस्बिरहरू)
# 2024-12-30 13:30:48,862 - INFO - Downloaded: कसलाई भेट्न उडिरहेकी होली पुतली?
# 2024-12-30 13:30:50,205 - INFO - Downloaded: चीनको यात्रा: सांघाई अध्यागमनमा पाएको दु:ख!
# 2024-12-30 13:30:51,532 - INFO - Downloaded: Untitled_88
# 2024-12-30 13:30:52,739 - INFO - Downloaded: Untitled_89
# 2024-12-30 13:30:54,868 - INFO - Downloaded: Untitled_90
# 2024-12-30 13:30:56,367 - INFO - Downloaded: Untitled_91
# 2024-12-30 13:30:58,176 - INFO - Downloaded: Untitled_92
# 2024-12-30 13:31:00,260 - INFO - Downloaded: Untitled_93
# 2024-12-30 13:31:01,604 - INFO - Downloaded: 'नेपालमा पनि कोही बस्छ र!'
# 2024-12-30 13:31:03,233 - INFO - Downloaded: यो किसिमको मेलमिलाप अब कहाँ पाउनु दाजुभाइमा!
# 2024-12-30 13:31:04,428 - INFO - Downloaded: मेरा बा!
# 2024-12-30 13:31:05,763 - INFO - Downloaded: संस्कारसहितको शिक्षा
# 2024-12-30 13:31:06,985 - INFO - Downloaded: त्रिवि सेवा आयोगलाई एक कर्मचारीको निवेदन- फेल हुन पाऊँ!
# 2024-12-30 13:31:08,067 - INFO - Downloaded: युनिकोडमा टाइप गर्नुहोस्
# 2024-12-30 13:31:09,180 - INFO - Downloaded: Untitled_100
# 2024-12-30 13:31:10,188 - WARNING - No image found for: Untitled_101
# 2024-12-30 13:31:11,196 - WARNING - No image found for: Untitled_102
# 2024-12-30 13:31:12,203 - WARNING - No image found for: Untitled_103
# 2024-12-30 13:31:13,210 - WARNING - No image found for: Untitled_104
# 2024-12-30 13:31:14,216 - WARNING - No image found for: Untitled_105
# 2024-12-30 13:31:15,222 - WARNING - No image found for: Untitled_106
# 2024-12-30 13:31:16,230 - WARNING - No image found for: Untitled_107
# 2024-12-30 13:31:17,237 - INFO - Scraped images and titles:
# 2024-12-30 13:31:17,239 - INFO - Title: नेप्सेले गर्‍यो सात कम्पनीको मूल्य समायोजन, नयाँ मूल्य कति?, Image URL: https://img.setoparty.com/uploads/posts/540X340/nepse-office5-1729612561.jpg
# 2024-12-30 13:31:17,240 - INFO - Title: 'नेपालमा पनि कोही बस्छ र!', Image URL: https://img.setoparty.com/uploads/posts/540X340/sanjeev-pokharel-1713875645.jpg
# 2024-12-30 13:31:17,241 - INFO - Title: चीनले ब्रह्मपुत्रमा बनाउन लागेको विशाल जलविद्युत आयोजनाले के असर गर्छ नेपाललाई?, Image URL: https://img.setoparty.com/uploads/posts/540X340/the-great-bend-1735495633.jpg
# 2024-12-30 13:31:17,242 - INFO - Title: छोराहरूले लत्तो छाडेको व्यवसाय सम्हालेर वर्षकै २० लाख कमाइरहेको दम्पती, Image URL: https://img.setoparty.com/uploads/posts/540X340/Pipla_Kulprasad-1732787774.JPG
# 2024-12-30 13:31:17,242 - INFO - Title: चालक र माली काम गर्ने आले दम्पतीले हुर्काएका चार सन्तान, Image URL: https://img.setoparty.com/uploads/posts/540X340/chet-bdr-and-wife-4-1724229398.jpg
# 2024-12-30 13:31:17,244 - INFO - Title: रातको चिया व्यापार, Image URL: https://img.setoparty.com/uploads/posts/540X340/chiya-wala--(4)-1732707216.jpg
# 2024-12-30 13:31:17,245 - INFO - Title: अब विकट छैन ‘बोबाङ गाउँ’, Image URL: https://img.setoparty.com/uploads/posts/540X340/Bobang-Gaun-1735543629.jpg
# 2024-12-30 13:31:17,246 - INFO - Title: कोरियामा सिकेर बेच्न थाले मासु, लगानी पुग्यो २ करोड, Image URL: https://img.setoparty.com/uploads/posts/540X340/haancook18-1735474874.jpg
# 2024-12-30 13:31:17,248 - INFO - Title: चौथो टेस्टमा भारतमाथि अस्ट्रेलियाको जित, सिरिजमा लियो अग्रता, Image URL: https://img.setoparty.com/uploads/posts/540X340/aus-winlj-1735540905.jpg
# 2024-12-30 13:31:17,248 - INFO - Title: भारत र अस्ट्रेलियाबीचको टेस्ट हेर्ने दर्शकको संख्याले बनायो कीर्तिमान, Image URL: https://img.setoparty.com/uploads/posts/540X340/record-nkh-mcg-1735539783.jpg
# 2024-12-30 13:31:17,249 - INFO - Title: सोमबार बढ्यो सुनको भाउ, कतिमा हुँदैछ किनबेच?, Image URL: https://img.setoparty.com/uploads/posts/540X340/gold silver1649223258.jpg
# 2024-12-30 13:31:17,250 - INFO - Title: १३ वर्षीया बालिकालाई जबरजस्ती घर भित्र्याउने युवक पक्राउ, Image URL: https://img.setoparty.com/uploads/posts/540X340/Arrested-symbolice-1733707720.jpg
# 2024-12-30 13:31:17,250 - INFO - Title: भक्तपुरका विभिन्न स्थानमा आज १० घन्टा विद्युत अवरूद्ध हुने, Image URL: https://img.setoparty.com/uploads/posts/540X340/power-cut-1713578172.jpg
# 2024-12-30 13:31:17,251 - INFO - Title: अमेरिकाका पूर्वराष्ट्रपति जिमी कार्टरको निधन, Image URL: https://img.setoparty.com/uploads/posts/540X340/jimmy-carter-1735524091.jpg
# 2024-12-30 13:31:17,252 - INFO - Title: घट्यो काठमाडौंको न्यूनतम तापक्रम, Image URL: https://img.setoparty.com/uploads/posts/540X340/chiso-ktm-(8)-ink-1735185766.jpeg
# 2024-12-30 13:31:17,252 - INFO - Title: यस्तो छ आजका लागि विदेशी मुद्राको विनिमयदर, Image URL: https://img.setoparty.com/uploads/posts/540X340/money-exchnage-rate1637638735.jpg
# 2024-12-30 13:31:17,252 - INFO - Title: थप एक नेपालीमा पुष्टि भयो मंकिपक्स, Image URL: https://img.setoparty.com/uploads/posts/540X340/Monkeypox-61658645871.jpg
# 2024-12-30 13:31:17,253 - INFO - Title: आज तमु ल्होसार मनाइँदै, Image URL: https://img.setoparty.com/uploads/posts/540X340/Tamu (1)1640853916.jpeg
# 2024-12-30 13:31:17,253 - INFO - Title: अखिल (क्रान्तिकारी) मा लाग्यो ३२ वर्ष उमेर हद, Image URL: https://img.setoparty.com/uploads/posts/540X340/akhil-krantikari-(23)-1727341774.jpeg
# 2024-12-30 13:31:17,254 - INFO - Title: यस्तो रहनेछ आज दिनभरिको मौसम, Image URL: https://img.setoparty.com/uploads/posts/540X340/mausam satelite1684546016.png
# 2024-12-30 13:31:17,254 - INFO - Title: जनमतको निर्देशन: पार्टी वा नेतृत्वबारे सामाजिक सञ्जालमा हरेक दिन एउटा सकारात्मक पोस्ट गर्नुपर्ने, Image URL: https://img.setoparty.com/uploads/posts/540X340/ck-raut--1719811987.jpg
# 2024-12-30 13:31:17,254 - INFO - Title: तीन जना एउटै कारमा गए, बाटोमा एक जनाको हत्या, Image URL: https://img.setoparty.com/uploads/posts/540X340/bara-murder-case-1735483516.jpg
# 2024-12-30 13:31:17,255 - INFO - Title: यसरी बन्दैछ १ हजार १२६ मिटर लामो सुरूङ (भिडिओ), Image URL: https://img.setoparty.com/uploads/posts/725X460/siddhababa-tunnel9-1735464748.jpg
# 2024-12-30 13:31:17,255 - INFO - Title: पिकनिक मनाउन जाँदा बाघको शिकार, Image URL: https://img.setoparty.com/uploads/posts/540X340/BaghStory-1735220884.jpeg
# 2024-12-30 13:31:17,256 - INFO - Title: गोवाबाट सिकेर पोखरामा स्ट्रिट फेस्टिभल (भिडिओ), Image URL: https://img.setoparty.com/uploads/posts/540X340/pokhara2-1735315284.jpeg
# 2024-12-30 13:31:17,256 - INFO - Title: ग्रिनल्यान्ड, पनामा र क्यानडामाथि नियन्त्रण जमाउने ट्रम्पको धम्की (भिडिओ), Image URL: https://img.setoparty.com/uploads/posts/540X340/Donald-Trump-01-1735291535.jpeg
# 2024-12-30 13:31:17,256 - INFO - Title: 'अहिलेको समयमा डेटा भनेको सुन हो', Image URL: https://img.setoparty.com/uploads/posts/540X340/rajan-thapaliya-1735232303.JPG
# 2024-12-30 13:31:17,257 - INFO - Title: लगातार हिट गीत गाइरहेका अर्जुन, Image URL: https://img.setoparty.com/uploads/posts/540X340/arjun-sapkota5-1735056563.jpg
# 2024-12-30 13:31:17,257 - INFO - Title: १६० किलो गाँजा र ट्रकसहित दुई जना पक्राउ, Image URL: https://img.setoparty.com/uploads/posts/540X340/Untitled-design-(12)-1735533672.jpg
# 2024-12-30 13:31:17,258 - INFO - Title: अखिल (क्रान्तिकारी)मा ३२ वर्षे उमेर हद लागु, माघ ५ गते मनोनयन दर्ता, Image URL: https://img.setoparty.com/uploads/posts/540X340/akhil-krantikari-(23)-1727341774.jpeg
# 2024-12-30 13:31:17,258 - INFO - Title: कुखुराको मासु खाँदा एक जनाको मृत्यु, तीन बिरामी, Image URL: https://img.setoparty.com/uploads/posts/540X340/setopati-1704025258.jpg
# 2024-12-30 13:31:17,259 - INFO - Title: तिम्बुङ पोखरी ।ताप्लेजुङको सिदिङ्वा गाउँपालिकास्थित धार्मिक तथा पर्यटकीयस्थल तिम्बुङ पोखरीको रमणीय दृश्य। तस्बिर: सन्तोष पुर्कुटी/रासस, Image URL: https://img.setoparty.com/uploads/posts/SP_TAPLEJUNG_timbungpokhari(1)-copy-1735539231.jpg
# 2024-12-30 13:31:17,259 - INFO - Title: कुहिरोले ढाकेको मङ्गगलसेन ।अछामको मंगलसेन नगरपालिका-६ ठुलासैनबाट सोमबार बिहान कुहिरोले ढाकेको अछाम सदरमुकाम मंगलसेन लगायत आसपासको क्षेत्र। तस्बिर: सुशील भण्डारी/रासस, Image URL: https://img.setoparty.com/uploads/posts/SB_ACHHAM_IMG20241229080437-copy-1735539231.jpg
# 2024-12-30 13:31:17,259 - INFO - Title: फेवातालमा ‘ड्रागन बोट रेस फेस्टिभल’ ।पोखरामा दोस्रो संस्करणको जारी ‘नेपाल–चीन मैत्रीपूर्ण ड्रागन बोट रेस फेस्टिभल’मा सोमबार पाँचसय मिटरको फाइनल खेलका लागि प्रतिस्पर्धा गर्दै चाइनिज टिम। तस्बिरः राधिका कँडेल/रासस, Image URL: https://img.setoparty.com/uploads/posts/RadhikaKandel-Pokhara-151000164026copy-copy-1735539231.jpg
# 2024-12-30 13:31:17,260 - INFO - Title: नुम्बुर हिमाल ।सोलुखुम्बुको सल्लेरीबाट सोमबार बिहान देखिएको सोलुखुम्बुस्थित नुम्बुर हिमाल। ६ हजार ९५८ मिटर उचाइमा रहेको रहेको यस हिमालमा अहिले हिउँ रित्तिँदै गएको छ। तस्बिर: सुवास दर्नाल/रासस, Image URL: https://img.setoparty.com/uploads/posts/SD_SOLI+UKHUMBU_IMG_20241230_070739-copy-1735539230.jpg
# 2024-12-30 13:31:17,261 - INFO - Title: साइपाल हिमाल ।बझाङ जिल्लाको साइपाल गाउँपालिकास्थित साइपाल हिमाल। सात हजार ३१ मिटर उचाइमा रहेको यो हिमालको फेदीमा पुग्न जिल्ला सदरमुकाम चैनपुरबाट करिब ६ दिन पैदल हिँड्नुपर्छ। तस्बिर: भूमिराज पिठातोली/रासस, Image URL: https://img.setoparty.com/uploads/posts/BRP_CHAINPUR_DSC0321-copy-1735539230.jpg
# 2024-12-30 13:31:17,262 - INFO - Title: 'बन्दीपुर भ्रमण वर्ष २०२५' आयोजना, पर्यटकको औसत बसाइ तीन दिन बनाइने, Image URL: https://img.setoparty.com/uploads/posts/540X340/bandipur-(1)-ink-1731294479.jpeg
# 2024-12-30 13:31:17,262 - INFO - Title: सोमबार बढ्यो सुनको भाउ, कतिमा हुँदैछ किनबेच?, Image URL: https://img.setoparty.com/uploads/posts/540X340/gold silver1649223258.jpg
# 2024-12-30 13:31:17,263 - INFO - Title: नेप्सेले गर्‍यो सात कम्पनीको मूल्य समायोजन, नयाँ मूल्य कति?, Image URL: https://img.setoparty.com/uploads/posts/540X340/nepse-office5-1729612561.jpg
# 2024-12-30 13:31:17,263 - INFO - Title: तीन साथीले २४ लाखमा खोलेको रेस्टुरेन्ट, अहिले काम गर्छन् ३५० जना, Image URL: https://img.setoparty.com/uploads/posts/540X340/trishara3-1735500652.jpg
# 2024-12-30 13:31:17,264 - INFO - Title: यसरी बन्दैछ १ हजार १२६ मिटर लामो सुरूङ (भिडिओ), Image URL: https://img.setoparty.com/uploads/posts/540X340/siddhababa-tunnel9-1735464748.jpg
# 2024-12-30 13:31:17,265 - INFO - Title: २६०९ विन्दुमा नेप्से, साढे पाँच अर्बको सेयर किनबेच, Image URL: https://img.setoparty.com/uploads/posts/540X340/share down1642501426.jpg
# 2024-12-30 13:31:17,265 - INFO - Title: लुक्लाबाट उडेको हेलिकप्टरमा ठोक्कियो चरा, साँगामा आकस्मिक अवतरण, Image URL: https://img.setoparty.com/uploads/posts/540X340/1575435552helicopter.jpg
# 2024-12-30 13:31:17,266 - INFO - Title: सोमबार भृकुटीमण्डपमा च्याउ मेला हुने, Image URL: https://img.setoparty.com/uploads/posts/540X340/mashroom-1735454323.jpg
# 2024-12-30 13:31:17,266 - INFO - Title: मन्त्री पाण्डेले गरे निर्माणाधीन नेपालगञ्ज विमानस्थल निरीक्षण, Image URL: https://img.setoparty.com/uploads/posts/540X340/mantri-pandey-1735453757.jpg
# 2024-12-30 13:31:17,266 - INFO - Title: परराष्ट्र मन्त्री राणाले गरिन् ५ अर्ब लगानीमा बन्ने जालपादेवी केबलकार शिलान्यास, Image URL: https://img.setoparty.com/uploads/posts/540X340/471208854_1133269018161830_6686724521519221329_n-1735448799.jpg
# 2024-12-30 13:31:17,267 - INFO - Title: घट्यो सुन–चाँदीको भाउ, आज कतिमा हुँदैछ किनबेच?, Image URL: https://img.setoparty.com/uploads/posts/540X340/gold1663737185.jpg
# 2024-12-30 13:31:17,267 - INFO - Title: बेनी–रणवाङ–दरवाङ सडक स्तरोन्नति हुँदै, Image URL: https://img.setoparty.com/uploads/posts/540X340/Ranabang-darbang-road-1735448630.jpg
# 2024-12-30 13:31:17,268 - INFO - Title: चितवनमा विद्युतीय कार एक्सपेङ जी सिक्सको बिक्री सुरु, Image URL: https://img.setoparty.com/uploads/posts/540X340/electric-car-1735447298.jpg
# 2024-12-30 13:31:17,268 - INFO - Title: पर्यटन प्रबर्द्धनका लागि मेघौलीदेखि बारपाकसम्म मोटरसाइकल राइडिङ, Image URL: https://img.setoparty.com/uploads/posts/540X340/riding-1735446703.jpg
# 2024-12-30 13:31:17,268 - INFO - Title: 'बन्दीपुर भ्रमण वर्ष २०२५' आयोजना, पर्यटकको औसत बसाइ तीन दिन बनाइने, Image URL: https://img.setoparty.com/uploads/posts/540X340/bandipur-(1)-ink-1731294479.jpeg
# 2024-12-30 13:31:17,269 - INFO - Title: नेपाल फ्रेट फरवार्डस एसोसिएसनको अध्यक्षमा राजेन्द्र संग्रौला निर्वाचित, Image URL: https://img.setoparty.com/uploads/posts/540X340/sangraula-1735535956.jpg
# 2024-12-30 13:31:17,269 - INFO - Title: नौ बुँदे घोषणा पत्र जारी गर्दै सकियो उद्योग तथा व्यवसाय महासंघको राष्ट्रिय भेला, Image URL: https://img.setoparty.com/uploads/posts/540X340/udhyog-1735480726.jpg
# 2024-12-30 13:31:17,269 - INFO - Title: 'मेरो नयाँ व्यवसायले नसोचेको सफलता दिएको छ', Image URL: https://img.setoparty.com/uploads/posts/540X340/aama-ko-nana12-1733918831.jpg
# 2024-12-30 13:31:17,270 - INFO - Title: फुर्सदमा सुरू भएको 'बौचा' लाई ब्रान्ड बनाउँदै महर्जन दम्पती, Image URL: https://img.setoparty.com/uploads/posts/540X340/bauchaa1-1731517385.jpg
# 2024-12-30 13:31:17,270 - INFO - Title: भारतबाट फर्केर 'निनो' बनाइरहेका उज्ज्वल, Image URL: https://img.setoparty.com/uploads/posts/540X340/nino1-1731430452.jpg
# 2024-12-30 13:31:17,271 - INFO - Title: खेर जाने कपडाका टुक्राबाट दिदीबहिनीले सुरू गरेको 'हिसी', Image URL: https://img.setoparty.com/uploads/posts/540X340/hisi-creation-dd-baini-1730744162.jpg
# 2024-12-30 13:31:17,271 - INFO - Title: महमा जमेकी महालक्ष्मी, Image URL: https://img.setoparty.com/uploads/posts/540X340/tbs-honey4-1729960507.jpg
# 2024-12-30 13:31:17,271 - INFO - Title: चौथो टेस्टमा भारतमाथि अस्ट्रेलियाको जित, सिरिजमा लियो अग्रता, Image URL: https://img.setoparty.com/uploads/posts/540X340/aus-winlj-1735540905.jpg
# 2024-12-30 13:31:17,272 - INFO - Title: भारत र अस्ट्रेलियाबीचको टेस्ट हेर्ने दर्शकको संख्याले बनायो कीर्तिमान, Image URL: https://img.setoparty.com/uploads/posts/540X340/record-nkh-mcg-1735539783.jpg
# 2024-12-30 13:31:17,272 - INFO - Title: उपाधि होडमा बलियो बन्दै लिभरपुल, Image URL: https://img.setoparty.com/uploads/posts/540X340/471581879_1167286248099538_8853076454877117818_n-1735538633.jpg
# 2024-12-30 13:31:17,272 - INFO - Title: मिसन–२०२६ : एसियाली खेलकुदमा स्वर्णसहित दोहोरो अंकमा पदक जित्ने लक्ष्य पूरा हुने विश्वास, Image URL: https://img.setoparty.com/uploads/posts/540X340/1000030661-1735485161.jpg
# 2024-12-30 13:31:17,273 - INFO - Title: नेपाल जुनियर इन्टरनेसनल सिरिज ब्याडमिन्टन : सूर्यक्ष र पारुललाई उपाधि, Image URL: https://img.setoparty.com/uploads/posts/540X340/Mix-double-Sahni-and-Negi-1735467672.jpg
# 2024-12-30 13:31:17,273 - INFO - Title: खेलका माध्यमबाट समृद्ध मुलुक निर्माणमा योगदान पुग्छ : मन्त्री चौधरी, Image URL: https://img.setoparty.com/uploads/posts/540X340/tejulal-chaudhary-1735193907.jpg
# 2024-12-30 13:31:17,273 - INFO - Title: भारतविरूद्ध अस्ट्रेलियाको अग्रता ३ सय रन नाघ्यो, Image URL: https://img.setoparty.com/uploads/posts/540X340/indvaustest-1735457785.jpg
# 2024-12-30 13:31:17,274 - INFO - Title: रहेनन् मलयालम अभिनेता दिलीप शंकर, Image URL: https://img.setoparty.com/uploads/posts/540X340/dilip-1735476058.jpg
# 2024-12-30 13:31:17,274 - INFO - Title: हरर फिल्म 'ममी' को टिजर सार्वजनिक (भिडिओ), Image URL: https://img.setoparty.com/uploads/posts/540X340/mami-1735472241.jpg
# 2024-12-30 13:31:17,275 - INFO - Title: व्यापार छाडेर संगीतमा लागे, ४ हजार बढीलाई सिकाइसके नाचगान, Image URL: https://img.setoparty.com/uploads/posts/540X340/suresh-senchuri3-1735401975.jpg
# 2024-12-30 13:31:17,275 - INFO - Title: यस्तो छ सलमान खानको 'सिकन्दर' को टिजर (भिडिओ), Image URL: https://img.setoparty.com/uploads/posts/540X340/sikandar-1735457751.jpg
# 2024-12-30 13:31:17,275 - INFO - Title: मञ्जु गौतमले ल्याइन् 'मुटुमा खिल बस्यो' (भिडिओ), Image URL: https://img.setoparty.com/uploads/posts/540X340/geet-1735455780.jpg
# 2024-12-30 13:31:17,276 - INFO - Title: एस एस राजामौलीको फिल्मबाट कमब्याक गर्दै प्रियंका, Image URL: https://img.setoparty.com/uploads/posts/540X340/priyanka-chopra-1718780850.jpg
# 2024-12-30 13:31:17,276 - INFO - Title: 'जन्ते बाख्रो' को काठमाडौंमा शुभमुहूर्त, Image URL: https://img.setoparty.com/uploads/posts/540X340/Jante-Bakhro-1735448834.jpg
# 2024-12-30 13:31:17,276 - INFO - Title: एनआरएनए महिला विभागले दियो बारबर्दिया नगर अस्पताललाई स्वास्थ्य उपकरण, Image URL: https://img.setoparty.com/uploads/posts/540X340/NRN-mahila-bivag-1735540890.jpg
# 2024-12-30 13:31:17,277 - INFO - Title: 'बच्चाको डाक्टर हुनु र आमा हुनु फरक रहेछ', Image URL: https://img.setoparty.com/uploads/posts/540X340/dr-rija-khanal-1725441966.jpg
# 2024-12-30 13:31:17,277 - INFO - Title: ९ महिनाअघि मात्रै क्यानडा आएकी थिइन्, सडक दुर्घटनामा परिन्, Image URL: https://img.setoparty.com/uploads/posts/canada-1714623038.jpg
# 2024-12-30 13:31:17,278 - INFO - Title: एनआरएनए एकता महाधिवेशनमा अवरोध नगर्न सर्वोच्चको पत्र, Image URL: https://img.setoparty.com/uploads/posts/540X340/supreme1611048845.jpg
# 2024-12-30 13:31:17,278 - INFO - Title: गैरआवासीय नेपाली नागरिकताको कार्यान्वयनका लागि सरकारको ध्यानाकर्षण, Image URL: https://img.setoparty.com/uploads/posts/540X340/citizenissue-1734085656.jpg
# 2024-12-30 13:31:17,278 - INFO - Title: अस्ट्रेलियामा गुञ्जिँदै सत्य-स्वरूप, Image URL: https://img.setoparty.com/uploads/posts/540X340/90e9c90b-14bc-44e4-8fe7-e0754d02f712-1732627634.jpg
# 2024-12-30 13:31:17,279 - INFO - Title: नेपालमय सिड्नी! (तस्बिरहरू), Image URL: https://img.setoparty.com/uploads/posts/540X340/australia-(1)-1732370878.jpg
# 2024-12-30 13:31:17,279 - INFO - Title: साहसिक साइक्लिङको नयाँ गन्तव्य च्योर्दोङ, Image URL: https://img.setoparty.com/uploads/posts/540X340/Cherdung-1-1735378333.jpg
# 2024-12-30 13:31:17,279 - INFO - Title: सिरानचोकमा क्होइबो धींले लोभ्याउँदैछ पर्यटक (तस्बिरहरू), Image URL: https://img.setoparty.com/uploads/posts/540X340/Khoibo-dhin-gorkha-(17)-1735359234.jpg
# 2024-12-30 13:31:17,280 - INFO - Title: चेर्दुङ डाँडामा साइकल सरर... (तस्बिरहरू), Image URL: https://img.setoparty.com/uploads/posts/540X340/cycle-1734689741.jpg
# 2024-12-30 13:31:17,280 - INFO - Title: कञ्चनजंघा पदमार्गको जरूरी सूचना!, Image URL: https://img.setoparty.com/uploads/posts/540X340/photo-no-1-&-Thumbnailjiwan-subedi-1734704948.jpg
# 2024-12-30 13:31:17,281 - INFO - Title: मलाई हरेक साल हिँडाएर हिमाल पुर्‍याउने संगीत!, Image URL: https://img.setoparty.com/uploads/posts/540X340/jiwan-subedi-main-pic-1734103319.jpg
# 2024-12-30 13:31:17,281 - INFO - Title: थोबो डाँडामा १२ सय पल्टनसँग पल्टिँदा (तस्बिरहरू), Image URL: https://img.setoparty.com/uploads/authors/85612400.jpg
# 2024-12-30 13:31:17,281 - INFO - Title: कसलाई भेट्न उडिरहेकी होली पुतली?, Image URL: https://img.setoparty.com/themes/setopati/images/noauthor.png
# 2024-12-30 13:31:17,282 - INFO - Title: चीनको यात्रा: सांघाई अध्यागमनमा पाएको दु:ख!, Image URL: https://img.setoparty.com/themes/setopati/images/noauthor.png
# 2024-12-30 13:31:17,283 - INFO - Title: Untitled_88, Image URL: https://www.setopati.com/uploads/bigyaapan/62208600.png
# 2024-12-30 13:31:17,283 - INFO - Title: Untitled_89, Image URL: https://www.setopati.com/uploads/bigyaapan/63399800.png
# 2024-12-30 13:31:17,284 - INFO - Title: Untitled_90, Image URL: https://www.setopati.com/uploads/bigyaapan/66281600.gif
# 2024-12-30 13:31:17,284 - INFO - Title: Untitled_91, Image URL: https://www.setopati.com/uploads/bigyaapan/66549600.gif
# 2024-12-30 13:31:17,284 - INFO - Title: Untitled_92, Image URL: https://www.setopati.com/uploads/bigyaapan/31161100.gif
# 2024-12-30 13:31:17,284 - INFO - Title: Untitled_93, Image URL: https://www.setopati.com/uploads/bigyaapan/88224300.gif
# 2024-12-30 13:31:17,285 - INFO - Title: 'नेपालमा पनि कोही बस्छ र!', Image URL: https://img.setoparty.com/uploads/authors/1541490450photo.jpg
# 2024-12-30 13:31:17,285 - INFO - Title: यो किसिमको मेलमिलाप अब कहाँ पाउनु दाजुभाइमा!, Image URL: https://img.setoparty.com/uploads/authors/65785600.jpg
# 2024-12-30 13:31:17,285 - INFO - Title: मेरा बा!, Image URL: https://www.setopati.com/uploads/posts/Rojika-Acharya-1735543712.jpg
# 2024-12-30 13:31:17,286 - INFO - Title: संस्कारसहितको शिक्षा, Image URL: https://img.setoparty.com/themes/setopati/images/noauthor.png
# 2024-12-30 13:31:17,286 - INFO - Title: त्रिवि सेवा आयोगलाई एक कर्मचारीको निवेदन- फेल हुन पाऊँ!, Image URL: https://www.setopati.com/uploads/posts/Bidur-Dahal-1715599339.jpg
# 2024-12-30 13:31:17,287 - INFO - Title: युनिकोडमा टाइप गर्नुहोस्, Image URL: https://www.setopati.com/themes/setopati/images/unicode.png
# 2024-12-30 13:31:17,287 - INFO - Title: Untitled_100, Image URL: https://www.setopati.com/themes/setopati/images/logo.svg?v=1.9

# %%
def scrape_ratopati_images(base_url, output_folder):
    try:
        headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
        response = requests.get(base_url, headers=headers)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')

        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        articles = soup.find_all('section', class_='breaking--special')
        images = []

        for index, article in enumerate(articles):
            title_tag = article.find('h2', class_='heading text--black')
            title = title_tag.text.strip() if title_tag else f"Untitled_{index}"
            sanitized_title = "_".join(title.split()).replace("/", "-")

            img_tag = article.find('img')
            if img_tag and 'src' in img_tag.attrs:
                img_url = urljoin(base_url, img_tag['src'])
                images.append({"title": title, "image_url": img_url})

                try:
                    img_response = requests.get(img_url, stream=True, headers=headers)
                    img_response.raise_for_status()

                    img_path = os.path.join(output_folder, f"{sanitized_title}_{index}.jpg")
                    with open(img_path, 'wb') as img_file:
                        for chunk in img_response.iter_content(1024):
                            img_file.write(chunk)

                    logging.info(f"Downloaded: {title}")
                except requests.exceptions.RequestException as e:
                    logging.error(f"Failed to download image for {title}: {e}")
            else:
                logging.warning(f"No image found for: {title}")

        
            time.sleep(1)

        return images

    except Exception as e:
        logging.error(f"An error occurred: {e}")
        return []

# %%
if __name__ == "__main__":
    base_url = "https://www.ratopati.com/"  
    output_folder = "ratopati_images"

    images_and_titles = scrape_ratopati_images(base_url, output_folder)
    print("Scraped images and titles:")
    for item in images_and_titles:
        print(f"Title: {item['title']}, Image URL: {item['image_url']}")
# Out:
# 2024-12-30 14:29:08,170 - INFO - Downloaded: भुटानी शरणार्थी प्रकरणमा चलखेल गरेको आरोपमा केन्द्रीय कारागारका डीएसपी तानिए
# Scraped images and titles:
# Title: भुटानी शरणार्थी प्रकरणमा चलखेल गरेको आरोपमा केन्द्रीय कारागारका डीएसपी तानिए, Image URL: https://rpcdn.ratopati.com/media/ratopati.jpg

# %%
def scrape_rajdhani_images(base_url, output_folder):
    try:
        headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
        response = requests.get(base_url, headers=headers)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')

        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        articles = soup.find_all('div', class_='elementor-post__text')
        images = []

        for index, article in enumerate(articles):
            title_tag = article.find('h3', class_='elementor-post__title')
            title = title_tag.text.strip() if title_tag else f"Untitled_{index}"
            sanitized_title = "_".join(title.split()).replace("/", "-")

            img_tag = article.find('img')
            if img_tag and 'src' in img_tag.attrs:
                img_url = urljoin(base_url, img_tag['src'])
                images.append({"title": title, "image_url": img_url})

                try:
                    img_response = requests.get(img_url, stream=True, headers=headers)
                    img_response.raise_for_status()

                    img_path = os.path.join(output_folder, f"{sanitized_title}_{index}.jpg")
                    with open(img_path, 'wb') as img_file:
                        for chunk in img_response.iter_content(1024):
                            img_file.write(chunk)

                    logging.info(f"Downloaded: {title}")
                except requests.exceptions.RequestException as e:
                    logging.error(f"Failed to download image for {title}: {e}")
            else:
                logging.warning(f"No image found for: {title}")

        
            time.sleep(1)

        return images

    except Exception as e:
        logging.error(f"An error occurred: {e}")
        return []

# %%
if __name__ == "__main__":
    base_url = "https://rajdhanidaily.com/"  
    output_folder = "rajdhani_images"

    images_and_titles = scrape_rajdhani_images(base_url, output_folder)
    print("Scraped images and titles:")
    for item in images_and_titles:
        print(f"Title: {item['title']}, Image URL: {item['image_url']}")
# Out:
# 2024-12-30 14:23:05,804 - INFO - Downloaded: भ्रष्टचारबिरूद्ध खबरदारी गर्ने प्रचण्ड ओलीको गृह जिल्लामा
# 2024-12-30 14:23:07,120 - INFO - Downloaded: मधेशी दलहरुबीच सहकार्यका लागि जसपा नेपालसँग वार्ता
# 2024-12-30 14:23:08,693 - INFO - Downloaded: नगद सहयोगले बिग्रिए राउटे समुदाय !
# 2024-12-30 14:23:09,698 - WARNING - No image found for: भ्रष्टचारबिरूद्ध खबरदारी गर्ने प्रचण्ड ओलीको गृह जिल्लामा
# 2024-12-30 14:23:10,705 - WARNING - No image found for: मधेशी दलहरुबीच सहकार्यका लागि जसपा नेपालसँग वार्ता
# 2024-12-30 14:23:11,711 - WARNING - No image found for: मधेशमा एमालेप्रति ग्राफ उच्च
# 2024-12-30 14:23:12,718 - WARNING - No image found for: सीडीएससीको सीईओमा प्रविन पन्दाक नियुक्त
# 2024-12-30 14:23:13,725 - WARNING - No image found for: इँटा उद्योगलाई अवरोध नगर्न अन्तरिम आदेश
# 2024-12-30 14:23:14,728 - WARNING - No image found for: सहकारीका पीडकहरू राजनीतिक दल खोल
# 2024-12-30 14:23:15,736 - WARNING - No image found for: वाग्मती, गोकर्ण र गया
# 2024-12-30 14:23:16,743 - WARNING - No image found for: एम पक्स महामारी र सार्वजनिक स्वास्थ्य चिन्ता
# 2024-12-30 14:23:17,751 - WARNING - No image found for: नगद सहयोगले बिग्रिए राउटे समुदाय !
# 2024-12-30 14:23:18,757 - WARNING - No image found for: पत्रकार महासंघ गण्डकीको पदस्थापन
# 2024-12-30 14:23:19,762 - WARNING - No image found for: बाघको आक्रमणबाट महिलाको ज्यान गयो
# 2024-12-30 14:23:20,768 - WARNING - No image found for: भारतका अत्यधिक प्रभावशाली अर्थविद् अर्थमन्त्रीको बिदाइ !
# 2024-12-30 14:23:21,776 - WARNING - No image found for: इतिहासकै तातो वर्ष २०२४
# 2024-12-30 14:23:22,783 - WARNING - No image found for: यो कोणबाट हेर्दा पीएल सिंहजस्तो देखिन्छन् !
# Scraped images and titles:
# Title: भ्रष्टचारबिरूद्ध खबरदारी गर्ने प्रचण्ड ओलीको गृह जिल्लामा, Image URL: https://rajdhanidaily.com/wp-content/uploads/2024/12/WhatsApp-Image-2024-12-23-at-17.02.13_21fd4df8.jpg-300x192.jpg
# Title: मधेशी दलहरुबीच सहकार्यका लागि जसपा नेपालसँग वार्ता, Image URL: https://rajdhanidaily.com/wp-content/uploads/2024/12/09ea674e-7836-4fe9-baee-ed2a68043ede-1024x612.jpeg
# Title: नगद सहयोगले बिग्रिए राउटे समुदाय !, Image URL: https://rajdhanidaily.com/wp-content/uploads/2024/12/2-raute-photo.jpg
